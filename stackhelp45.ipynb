(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+---------+--------+-----------+-------+-----------+
#            DateTime|MsgSeqNum|SensorId|CommandCode|DataLen|BatteryVolt|
# +-------------------+---------+--------+-----------+-------+-----------+
# 2020-02-25 11:50:34|       38|0000796D|         35|      2|         23|
# 2020-02-25 11:50:35|       38|0000796D|         35|      2|         23|
# 2020-02-26 11:52:35|       38|0000796D|         35|      2|         23|
# 2020-02-27 11:52:35|       38|0000796D|         35|      2|         23|
# 2020-02-28 11:52:35|       38|0000796D|         35|      2|         23|
# ...

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

w=Window().partitionBy("SensorId").orderBy("DateTime")
w5=Window().partitionBy("SensorID","BatteryVolt","inc_sum").orderBy("DateTime")
w6=Window().partitionBy("SensorID","BatteryVolt","inc_sum")
w2=Window().partitionBy("SensorId","inc_sum").orderBy("DateTime")
w3=Window().partitionBy("SensorId","inc_sum")
w4=Window().partitionBy("DateTime","SensorId","inc_sum").orderBy("DateTime")
df.withColumn("lag", F.lag("BatteryVolt").over(w))\
.withColumn("lag", F.when(F.col("lag").isNull(),F.lit(-1)).otherwise(F.col("lag")))\
.withColumn("inc_sum", F.when((F.col("BatteryVolt")=='24')\
& (F.col("lag")!='24'),F.lit(1)).otherwise(F.lit(0)))\
.withColumn("inc_sum", F.sum("inc_sum").over(w))\
.withColumn("row_num", F.row_number().over(w2))\
.withColumn("first", F.min("row_num").over(w3))\
.withColumn("max", F.max("row_num").over(w3))\
.withColumn("cor", F.row_number().over(w5))\
.withColumn("maxcor", F.max("cor").over(w6))\
.withColumn("maxcor", F.when((F.col("BatteryVolt")=='24') | (F.col("BatteryVolt")=='1F'), F.lit(None)).otherwise(F.col("maxcor"))).filter('row_num=first or row_num=max or cor=maxcor')\
.select("DateTime", "SensorId","BatteryVolt","inc_sum")\
.withColumn("all1", F.collect_list("BatteryVolt").over(w3))\
.withColumn("all", F.array(*[F.lit(x) for x in ['24','23','22','21','20','1F']]))\
.withColumn("except", F.array_except("all","all1"))\
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt")=='1F', F.lit(2)).otherwise(F.col("BatteryVolt")))\
.withColumn("except", F.expr("filter(except, x-> int(x)+1=int(BatteryVolt))")[0])\
.withColumn("BatteryVolt", F.when(F.col("except").isNotNull(), F.expr("""sequence(int(except)+(int(BatteryVolt)-int(except)),int(except),-1)""")).otherwise(F.array("BatteryVolt")))\
.select("DateTime","SensorId",F.explode("BatteryVolt").alias("BatteryVolt"),"except","inc_sum")\
.withColumn("DateTime", F.when(F.col("except")==F.col("BatteryVolt"),F.lit(0)).otherwise(F.col("DateTime")))\
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','2'])))\
.select("SensorId", "zip.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("2").alias("5th_change"))\
.replace('0',"datamiss").show()

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.functions import when

w=Window().partitionBy("SensorID").orderBy("DateTime")
w5=Window().partitionBy("SensorID","BatteryVolt","inc_sum").orderBy("DateTime")
w6=Window().partitionBy("SensorID","BatteryVolt","inc_sum")
w2=Window().partitionBy("SensorId","inc_sum").orderBy("DateTime")
w3=Window().partitionBy("SensorId","inc_sum")
w4=Window().partitionBy("DateTime","SensorId","inc_sum").orderBy("DateTime")
df.withColumn("lag", F.lag("BatteryVolt").over(w))\
.withColumn("lag", F.when(F.col("lag").isNull(),F.lit(-1)).otherwise(F.col("lag")))\
.withColumn("inc_sum", F.when((F.col("BatteryVolt")=='24')\
& (F.col("lag")!='24'),F.lit(1)).when((F.col("BatteryVolt")=='23')\
& (F.col("lag")!='24')&(F.col("lag")!='23'),F.lit(1)).otherwise(F.lit(0)))\
.withColumn("inc_sum", F.sum("inc_sum").over(w))\
.withColumn("row_num", F.row_number().over(w2))\
.withColumn("first", F.min("row_num").over(w3))\
.withColumn("max", F.max("row_num").over(w3))\
.withColumn("cor", F.row_number().over(w5))\
.withColumn("maxcor", F.max("cor").over(w6))\
.withColumn("maxcor", F.when((F.col("BatteryVolt")=='24') | (F.col("BatteryVolt")=='1F'), F.lit(None)).otherwise(F.col("maxcor"))).filter('row_num=first or row_num=max or cor=maxcor')\
.select("DateTime", "SensorId","BatteryVolt","inc_sum")\
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt")=='1F', F.lit(19)).otherwise(F.col("BatteryVolt")))\
.withColumn("all1", F.collect_list("BatteryVolt").over(w3))\
.withColumn("all", F.array(*[F.lit(x) for x in ['24','23','22','21','20','19']]))\
.withColumn("except", F.when(F.size("all1")!=F.size("all"),F.array_except("all","all1")).otherwise(F.array(F.lit(None))))\
.withColumn("except2", F.flatten(F.array("all1","except")))\
.withColumn("except2", F.expr("""filter(except2,x-> x!='null')""")).drop("all1","all","except")\
.groupBy("SensorId","inc_sum").agg(F.collect_list("DateTime").alias("DateTime"),\
                                   F.collect_list("BatteryVolt").alias("BatteryVolt"),\
                                   F.first("except2").alias("except2"))\
.withColumn("zip", F.explode(F.arrays_zip("DateTime","BatteryVolt","except2")))\
.select("SensorId","zip.*","inc_sum")\
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt").isNull(), F.col("except2")).otherwise(F.col("BatteryVolt")))\
.withColumn("DateTime", F.when(F.col("DateTime").isNull(), F.lit(0)).otherwise(F.col("DateTime")))\
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zipped", F.explode(F.arrays_zip(*['24','23','22','21','20','19'])))\
.select("SensorId", "zipped.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("19").alias("5th_change"))\
.replace('0',"datamiss").dropna().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-------------------+-------------------+-------------------+----------+-------------------+-------------------+
# SensorId|        start_point|         1st_change|         2nd_change|3rd_change|         4th_change|         5th_change|
# +--------+-------------------+-------------------+-------------------+----------+-------------------+-------------------+
# 0000796D|           datamiss|2020-02-25 11:50:34|           datamiss|  datamiss|           datamiss|2020-04-22 12:17:45|
# 0000796D|           datamiss|2020-02-28 11:52:35|2020-05-01 12:26:45|  datamiss|2020-05-05 12:29:45|2020-05-09 12:26:45|
# ...

# %%
.groupBy("inc_sum").agg(F.collect_list("DateTime").alias("DateTime"),F.collect_list("BatteryVolt").alias("BatteryVolt")\
                       ,F.first("except2").alias("except2"),F.first("SensorId").alias("SensorId"))\
.withColumn("zip", F.explode(F.arrays_zip("DateTime","BatteryVolt","except2")))\
.select("SensorId","zip.*","inc_sum")\
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt").isNull(), F.col("except2")).otherwise(F.col("BatteryVolt")))\
.withColumn("DateTime", F.when(F.col("DateTime").isNull(), F.lit(0)).otherwise(F.col("DateTime")))\
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zipped", F.explode(F.arrays_zip(*['24','23','22','21','20','19'])))\
.select("SensorId", "zipped.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("19").alias("5th_change"))\
.replace('0',"datamiss").dropna()\
.show()

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.functions import when

w=Window().partitionBy("SensorId").orderBy("DateTime")
w5=Window().partitionBy("SensorID","BatteryVolt","inc_sum").orderBy("DateTime")
w6=Window().partitionBy("SensorID","BatteryVolt","inc_sum")
w2=Window().partitionBy("SensorId","inc_sum").orderBy("DateTime")
w3=Window().partitionBy("SensorId","inc_sum")
w4=Window().partitionBy("DateTime","SensorId","inc_sum").orderBy("DateTime")
df.withColumn("lag", F.lag("BatteryVolt").over(w))\
.withColumn("lag", F.when(F.col("lag").isNull(),F.lit(-1)).otherwise(F.col("lag")))\
.withColumn("inc_sum", F.when((F.col("BatteryVolt")==24)\
& (F.col("lag")!='24'),F.lit(1)).otherwise(F.lit(0)))\
.withColumn("inc_sum", F.sum("inc_sum").over(w))\
.withColumn("row_num", F.row_number().over(w2))\
.withColumn("first", F.min("row_num").over(w3))\
.withColumn("max", F.max("row_num").over(w3))\
.withColumn("cor", F.row_number().over(w5))\
.withColumn("maxcor", F.max("cor").over(w6))\
.withColumn("maxcor", F.when((F.col("BatteryVolt")=='24') | (F.col("BatteryVolt")=='1F'), F.lit(None)).otherwise(F.col("maxcor"))).filter('row_num=first or row_num=max or cor=maxcor')\
.select("DateTime", "SensorId","BatteryVolt","inc_sum")\
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt")=='1F', F.lit(19)).otherwise(F.col("BatteryVolt")))\
.withColumn("all1", F.collect_list("BatteryVolt").over(w3))\
.withColumn("all", F.array(*[F.lit(x) for x in ['24','23','22','21','20','19']]))\
.withColumn("except", F.when(F.size("all1")!=F.size("all"),F.array_except("all","all1")).otherwise(F.array(F.lit(None))))\
.withColumn("except2", F.flatten(F.array("all1","except")))\
.withColumn("except2", F.expr("""filter(except2,x-> x!='null')""")).drop("all1","all","except")\
.groupBy("inc_sum").agg(F.collect_list("DateTime").alias("DateTime"),F.collect_list("BatteryVolt").alias("BatteryVolt")\
                       ,F.first("except2").alias("except2"),F.first("SensorId").alias("SensorId"))\
.withColumn("zip", F.explode(F.arrays_zip("DateTime","BatteryVolt","except2")))\
.select("SensorId","zip.*","inc_sum")\
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt").isNull(), F.col("except2")).otherwise(F.col("BatteryVolt")))\
.withColumn("DateTime", F.when(F.col("DateTime").isNull(), F.lit(0)).otherwise(F.col("DateTime")))\
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zipped", F.explode(F.arrays_zip(*['24','23','22','21','20','19'])))\
.select("SensorId", "zipped.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("19").alias("5th_change"))\
.replace('0',"datamiss")\
.show()

# %%
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zipped", F.explode(F.arrays_zip(*['24','23','22','21','20','19'])))\
.select("SensorId", "zipped.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("19").alias("5th_change"))\
.replace('0',"datamiss")\
.show()

# %%
.withColumn("except", F.expr("filter(except, x-> int(x)+1=int(BatteryVolt))")[0])\
.withColumn("BatteryVolt", F.when(F.col("except").isNotNull(), F.expr("""sequence(int(except)+(int(BatteryVolt)-int(except)),int(except),-1)""")).otherwise(F.array("BatteryVolt")))\
.select("DateTime","SensorId",F.explode("BatteryVolt").alias("BatteryVolt"),"except","inc_sum")\
.withColumn("DateTime", F.when(F.col("except")==F.col("BatteryVolt"),F.lit(0)).otherwise(F.col("DateTime")))\
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','19'])))\
.select("SensorId", "zip.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("19").alias("5th_change"))\
.show()

# %%
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','1F'])))\
.select("SensorId", "zip.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("1F").alias("5th_change"))\
.replace('0',"datamiss").show()

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.functions import when

w=Window().partitionBy("SensorId").orderBy("DateTime")
w5=Window().partitionBy("SensorID","BatteryVolt","inc_sum").orderBy("DateTime")
w6=Window().partitionBy("SensorID","BatteryVolt","inc_sum")
w2=Window().partitionBy("SensorId","inc_sum").orderBy("DateTime")
w3=Window().partitionBy("SensorId","inc_sum")
w4=Window().partitionBy("DateTime","SensorId","inc_sum").orderBy("DateTime")
df.withColumn("lag", F.lag("BatteryVolt").over(w))\
.withColumn("lag", F.when(F.col("lag").isNull(),F.lit(-1)).otherwise(F.col("lag")))\
.withColumn("inc_sum", F.when((F.col("BatteryVolt")==24)\
& (F.col("lag")!='24'),F.lit(1)).otherwise(F.lit(0)))\
.withColumn("inc_sum", F.sum("inc_sum").over(w))\
.withColumn("row_num", F.row_number().over(w2))\
.withColumn("first", F.min("row_num").over(w3))\
.withColumn("max", F.max("row_num").over(w3))\
.withColumn("cor", F.row_number().over(w5))\
.withColumn("maxcor", F.max("cor").over(w6))\
.withColumn("maxcor", F.when((F.col("BatteryVolt")=='24') | (F.col("BatteryVolt")=='1F'), F.lit(None)).otherwise(F.col("maxcor"))).filter('row_num=first or row_num=max or cor=maxcor')\
.select("DateTime", "SensorId","BatteryVolt","inc_sum")\
.withColumn("all1", F.collect_list("BatteryVolt").over(w3))\
.withColumn("all", F.array(*[F.lit(x) for x in ['24','23','22','21','20','1F']]))\
.withColumn("except", F.element_at(F.array_except("all","all1"),-1))\
.withColumn("BatteryVolt", F.when(F.col("except")+1<=F.col("BatteryVolt"), F.expr("""sequence(int(except)+(int(BatteryVolt)-int(except)),int(except),-1)"""))\
.otherwise(F.expr("""sequence(int(BatteryVolt),int(BatteryVolt),0)""")))\
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt").isNull(), F.array(F.lit(2))).otherwise(F.col("BatteryVolt")))\
.select("DateTime","SensorId",F.explode("BatteryVolt").alias("BatteryVolt"),"inc_sum")\
.withColumn("rownum2", F.row_number().over(w4))\
.withColumn("DateTime", F.when((F.col("rownum2")>1), F.lit(0))\
.otherwise(F.col("DateTime"))).orderBy("DateTime")\
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','2'])))\
.select("SensorId", "zip.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("2").alias("5th_change"))\
.replace('0',"datamiss").show()

# %%
.withColumn("BatteryVolt", F.when(F.col("BatteryVolt").isNull(), F.array(F.lit(2))).otherwise(F.col("BatteryVolt")))\
.select("DateTime","SensorId",F.explode("BatteryVolt").alias("BatteryVolt"),"inc_sum")\
.withColumn("rownum2", F.row_number().over(w4))\
.withColumn("DateTime", F.when((F.col("rownum2")>1), F.lit(0))\
.otherwise(F.col("DateTime"))).orderBy("DateTime")\
.groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
.withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','2'])))\
.select("SensorId", "zip.*")\
.select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("2").alias("5th_change"))\
.replace('0',"datamiss").show()

# %%
.withColumn("rownum2", F.row_number().over(w4))\
        .withColumn("DateTime", F.when((F.col("rownum2")>1), F.lit(0))\
                    .otherwise(F.col("DateTime"))).orderBy("DateTime")\
        .groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
        .withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','2'])))\
        .select("SensorId", "zip.*")\
        .select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
                ,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("2").alias("5th_change"))\
                .replace('0',"datamiss").show()

# %%
.drop("yo","row_num","first","max")\
        .filter("row_num=first or row_num=max or cor='change'")\
        .withColumn("all1", F.collect_list("BatteryVolt").over(w3))\
        .withColumn("all", F.array(*[F.lit(x) for x in ['24','23','22','21','20','1F']]))\
        .withColumn("except", F.array_except("all","all1")[0])\
        .withColumn("BatteryVolt", F.when(F.col("except")+1==F.col("BatteryVolt"), F.expr("""sequence(int(except)+1,int(except),-1)"""))\
                    .otherwise(F.expr("""sequence(int(BatteryVolt),int(BatteryVolt),0)""")))\
        .withColumn("BatteryVolt", F.when(F.col("BatteryVolt").isNull(), F.array(F.lit(2))).otherwise(F.col("BatteryVolt")))\
        .select("DateTime","SensorId",F.explode("BatteryVolt").alias("BatteryVolt"),"inc_sum")\
        .withColumn("rownum2", F.row_number().over(w4))\
        .withColumn("DateTime", F.when((F.col("rownum2")>1), F.lit(0))\
                    .otherwise(F.col("DateTime"))).orderBy("DateTime")\
        .groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
        .withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','2'])))\
        .select("SensorId", "zip.*")\
        .select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
                ,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("2").alias("5th_change"))\
                .replace('0',"datamiss").show()

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
w=Window().partitionBy("BatteryVolt").orderBy("DateTime")
w1=Window().partitionBy("SensorId").orderBy("DateTime")
w2=Window().partitionBy("SensorId","inc_sum").orderBy("DateTime")
w3=Window().partitionBy("SensorId","inc_sum")
w4=Window().partitionBy("DateTime","SensorId","inc_sum").orderBy("DateTime")
df.withColumn("cor",F.row_number().over(w))\
  .withColumn("yo", F.when((F.col("cor")%2!=0) & (F.col("BatteryVolt")==24),F.lit(1)).otherwise(F.lit(0)))\
  .withColumn("inc_sum", F.sum("yo").over(w1))\
  .withColumn("cor", F.when((F.col("BatteryVolt")!=24) & (F.col("cor")%2==0), F.lit('change')).otherwise(F.lit('no')))\
        .withColumn("row_num", F.row_number().over(w2))\
        .withColumn("first", F.min("row_num").over(w3))\
        .withColumn("max", F.max("row_num").over(w3)).drop("yo","row_num","first","max")\
        .filter("row_num=first or row_num=max or cor='change'")\
        .withColumn("all1", F.collect_list("BatteryVolt").over(w3))\
        .withColumn("all", F.array(*[F.lit(x) for x in ['24','23','22','21','20','1F']]))\
        .withColumn("except", F.array_except("all","all1")[0])\
        .withColumn("BatteryVolt", F.when(F.col("except")+1==F.col("BatteryVolt"), F.expr("""sequence(int(except)+1,int(except),-1)"""))\
                    .otherwise(F.expr("""sequence(int(BatteryVolt),int(BatteryVolt),0)""")))\
        .withColumn("BatteryVolt", F.when(F.col("BatteryVolt").isNull(), F.array(F.lit(2))).otherwise(F.col("BatteryVolt")))\
        .select("DateTime","SensorId",F.explode("BatteryVolt").alias("BatteryVolt"),"inc_sum")\
        .withColumn("rownum2", F.row_number().over(w4))\
        .withColumn("DateTime", F.when((F.col("rownum2")>1), F.lit(0))\
                    .otherwise(F.col("DateTime"))).orderBy("DateTime")\
        .groupBy("SensorId").pivot("BatteryVolt").agg((F.collect_list("DateTime")))\
        .withColumn("zip", F.explode(F.arrays_zip(*['24','23','22','21','20','2'])))\
        .select("SensorId", "zip.*")\
        .select("SensorId", F.col("24").alias("start_point"),F.col("23").alias("1st_change"),F.col("22").alias("2nd_change")\
                ,F.col("21").alias("3rd_change"),F.col("20").alias("4th_change"),F.col("2").alias("5th_change"))\
                .replace('0',"datamiss").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+
# SensorId|        start_point|         1st_change|         2nd_change|         3rd_change|         4th_change|         5th_change|
# +--------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+
# 0000796D|2020-02-23 11:42:34|           datamiss|2020-03-02 11:12:35|2020-03-07 10:32:45|2020-03-14 11:12:45|2020-05-09 12:26:45|
# ...

# %%
list=[[2,          1],
[3,          1],
[4 ,         1],
[5  ,        2],
[2     ,     7],
[3      ,    7],
[8       ,   9],
[10      ,   12],
[11       ,  8],
[15        , 14],
[13        , 15],
[14         ,10]]

df=spark.createDataFrame(list,['duplicate','parent'])


df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+------+
# duplicate|parent|
# +---------+------+
#         2|     1|
#         3|     1|
#         4|     1|
#         5|     2|
#         2|     7|
#         3|     7|
#         8|     9|
#        10|    12|
#        11|     8|
#        15|    14|
#        13|    15|
#        14|    10|
# +---------+------+
#
# </div>

# %%
df.groupBy("duplicate").agg(F.collect_list("parent").alias("parent")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+------+
# duplicate|parent|
# +---------+------+
#         5|   [2]|
#        10|  [12]|
#         3|[1, 7]|
#         8|   [9]|
#        11|   [8]|
#         2|[1, 7]|
#         4|   [1]|
#        13|  [15]|
#        14|  [10]|
#        15|  [14]|
# +---------+------+
#
# </div>
